# %% [markdown]
# ## Description of the Problem

# %%
# The objective of this project is to implement a framework where the knowedge of bayesian uncertainty can be combined with Deep Learning Models
# The original idea of incorporating bayesian statistics in deep learning models was proposed by Yarin Gal (2016), and here we shall implement that concept utilising the capability of dropout layers to add uncertainty to the model outcome during testing
# The data for this project has been downloaded from https://www.isic-archive.com/#!/topWithHeader/wideContentTop/main
# This is an image data set comprising of malignant and non-malignant skin cancers, and has both binary (Melanoma/Other) as well as multi-class classification labels
# For the purpose of this project, we will use binary labels and assess the change in accuracy of the model for scenarios where the model can predict the outcome witout uncertainty, v/s when the model declares its uncertainty about the outcome
# We have developed our own custom model, and have also assessed the performance of three transfer learning models: MobileNet, DenseNet and NASNet
# We finally used DenseNet201 on the Test Sample and for incorporating the uncertainty, because it was performing the best on training and validation data

# %% [markdown]
# ## Environment

# %%
# We utilised Google's cloud platform (https://cloud.google.com) to develop our models, test and train them
# The first step was to import the image data set and the .csv file containing the image labels to the working directory
# Once the folder containing image files (ISIC_2019_Training_Input) and the .csv file containing the image labels (ISIC_2019_Training_GroundTruth.csv) have been imported to the working directory, the following code would first create data frame containing binary labels for the corresponding image filenames
# These filenames are then used by the image generator to load random samples of images for test and validation, and the binary labels are used from the labels created earlier

# %% [markdown]
# ## Importing all Libraries

# %%
#Importing Utilities
import os
from glob import glob
import copy
import os
import time
import datetime
from PIL import Image
import sys
import warnings
warnings.filterwarnings("ignore")
import json,codecs

# data tools
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tqdm

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dense, Dropout, Input,Conv2D, MaxPooling2D, BatchNormalization
import sklearn.model_selection as model_selection
import keras
import tensorflow as tf

#Metrics
from sklearn.metrics import precision_score , recall_score
from  tensorflow.keras.models import Sequential, Model
from keras.metrics import binary_accuracy
from keras.metrics import categorical_accuracy
from sklearn.metrics import roc_curve, auc

#Transfer learning models
from keras.applications.densenet import DenseNet201
from keras.applications.nasnet import NASNetMobile
from keras.applications.mobilenet import MobileNet 

plt.style.use("ggplot")
# %matplotlib inline

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Defining the Data Loader for generating image label dataframe

# %%
def processLabelDf(file):
    # load file into df and set image name as index
    df = pd.read_csv(file)
    df = df.set_index("image")

    # create list of class labels from column header
    classes = df.columns

    # create multiclass and binary class labels, remove original columns
    df["multi"] = ""
    for label in classes:
        df["multi"] = np.where(df[label] == 1, label, df["multi"])
        df = df.drop(label, axis=1)

    df["binary"] = np.where(df["multi"] == "MEL", "MEL", "NONMEL")

    return df

# %% [markdown]
# ## Loading File names from directory and generating labels data frame using function described earlier

# %%
labelDf = processLabelDf(
    file="ISIC_2019_Training_GroundTruth.csv"
)
labelDf[:10]
# Out:
#              multi  binary
# image
# ISIC_0000000    NV  NONMEL
# ISIC_0000001    NV  NONMEL
# ISIC_0000002   MEL     MEL
# ISIC_0000003    NV  NONMEL
# ISIC_0000004   MEL     MEL
# ISIC_0000006    NV  NONMEL
# ISIC_0000007    NV  NONMEL
# ISIC_0000008    NV  NONMEL
# ISIC_0000009    NV  NONMEL
# ISIC_0000010    NV  NONMEL

# %%
a=labelDf.sample(frac=1)
Train = a[:20000]
Test = a[20001:]

# %%
Test['image'] = Test.index

# %%
for i in range(len(Test)):
    Test['image'][i]=Test['image'][i]+".jpg"

# %%
Test.columns
# Out:
# Index(['multi', 'binary', 'image'], dtype='object')

# %% [markdown]
# ## Loading Test Image Generator

# %%
datagen = ImageDataGenerator(
    rescale = 1/255,
    rotation_range = 270,
    horizontal_flip = True,
    validation_split=00.0)

# %%
test_datagen=ImageDataGenerator(rescale=1./255.)
test_generator=test_datagen.flow_from_dataframe(
    dataframe=Test,
    directory="./ISIC_2019_Training_Input",
    x_col="image",
    y_col="binary",
    batch_size=100,
    seed=42,
    shuffle=True,
    class_mode="categorical",
    target_size=(256,256))
# Out:
# Found 5330 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Loading 100 test images

# %%
Test_img, Test_lab = test_generator.next()
pd.DataFrame(Test_lab)[0].value_counts() / len(Test_lab)
# Out:
# 0.0    0.73
# 1.0    0.27
# Name: 0, dtype: float64

# %%
len(Test_lab)
# Out:
# 100

# %% [markdown]
# ## Testing on the Densenet Model which performed best on the validation data

# %%
Testing_Model = tf.keras.models.load_model('./Deep Learning Project_Dr50/DenseNet_model_dr_final_50_13_12.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
Predictions = Testing_Model.predict(Test_img)

# %% [markdown]
# ## Inverting(Correcting) Predictions and Labels (1=Melanoma; 0=Non-Melanoma)
# (So that Pred_bin variables yields 1 for Melanoma and 0 for Non-Melanoma)

# %%
for i in range(len(Predictions)):
    temp=Predictions[i][0]
    Predictions[i][0]=Predictions[i][1]
    Predictions[i][1]=temp

# %%
Pred_bin=[]
for y_p in Predictions:
    p = y_p.argmax(axis=0)
    Pred_bin.append(p)

# %% [markdown]
# ## Model Accuracy on Test Set

# %%
accs = 0
for i in range(len(Pred_bin)):
    if(pd.DataFrame(Test_lab)[0][i]== Pred_bin[i]):
      accs=accs+1  
print("Accuracy on the Test Sample for the Best Model: {:.1%}".format((accs)/len(Pred_bin)))
# Out:
# Accuracy on the Test Sample for the Best Model: 83.0%

# %% [markdown]
# ## Initial Predictions before accounting for Model Uncertainty

# %%
y_score = []
for index in range(len(Test_lab)): #compute one at a time due to memory constraints
    print("Predicted values..." + "Melanoma : ", Predictions[index][1], " | Other : ", Predictions[index][0])
    print("Real values..." + "Melanoma : ", Test_lab[index][0], " | Other : ", Test_lab[index][1])
    print("---------------------------------------------------------------------------")
# Out:
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0011755447  | Other :  0.9988244
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9041531  | Other :  0.09584682
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.5315034e-05  | Other :  0.99998474
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.014484862  | Other :  0.9855151
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.05423779  | Other :  0.9457622
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.4700817e-09  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.09524019  | Other :  0.90475976
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  9.505901e-05  | Other :  0.999905
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.2972887e-23  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.7313495  | Other :  0.26865047
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.985601  | Other :  0.014398994
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0058270046  | Other :  0.994173
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0004792856  | Other :  0.9995208
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  6.506337e-07  | Other :  0.9999994
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99869746  | Other :  0.001302589
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.014585648  | Other :  0.9854144
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0013269375  | Other :  0.9986731
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0034444486  | Other :  0.99655557
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  6.643927e-05  | Other :  0.9999336
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99616855  | Other :  0.0038314771
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.25632548  | Other :  0.74367446
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.18897234  | Other :  0.81102765
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  5.319883e-38  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00012852286  | Other :  0.9998715
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  5.646348e-14
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999883  | Other :  1.1659518e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9986094  | Other :  0.0013905978
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.51305383  | Other :  0.48694614
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9124487  | Other :  0.08755131
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.92758197  | Other :  0.07241802
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.3904843  | Other :  0.6095157
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00022546168  | Other :  0.9997745
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  3.8548997e-06  | Other :  0.9999962
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  8.437029e-05  | Other :  0.9999156
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  8.3354573e-10  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.07395696  | Other :  0.92604303
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.895638  | Other :  0.104362026
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.16307333  | Other :  0.83692664
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.49669582  | Other :  0.5033042
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.008632952  | Other :  0.99136704
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9994099  | Other :  0.0005901145
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0022974645  | Other :  0.99770254
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0061122915  | Other :  0.9938877
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.977514  | Other :  0.022485964
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.08781442  | Other :  0.91218555
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.04793492  | Other :  0.95206505
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  4.1012258e-14
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00090565835  | Other :  0.99909437
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.97540164  | Other :  0.024598334
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.4961458e-07  | Other :  0.9999999
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.02697327  | Other :  0.9730267
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9925114  | Other :  0.007488618
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  6.071169e-06  | Other :  0.9999939
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.5196383  | Other :  0.4803617
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.1201301e-05  | Other :  0.9999888
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.9054804e-06  | Other :  0.9999981
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.6426393  | Other :  0.35736075
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.20923048  | Other :  0.7907695
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  5.988654e-09  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  4.6356918e-10  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.86189306  | Other :  0.13810693
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99725074  | Other :  0.0027492845
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0020190717  | Other :  0.997981
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9182926  | Other :  0.08170746
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.95027804  | Other :  0.049721986
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  3.3809076e-05  | Other :  0.99996614
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00016042202  | Other :  0.99983954
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  7.9351945e-38  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.1086043e-07  | Other :  0.9999999
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.1545299  | Other :  0.8454701
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9821812  | Other :  0.017818838
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.49012256  | Other :  0.50987744
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  9.678149e-15  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  5.0176228e-09  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99999034  | Other :  9.624238e-06
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.1358287e-20  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  6.324352e-07  | Other :  0.9999994
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00010899135  | Other :  0.99989104
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.96095514  | Other :  0.039044857
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0077733686  | Other :  0.9922266
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.32459354  | Other :  0.6754065
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99969923  | Other :  0.00030078864
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.6248948  | Other :  0.37510514
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.008637434  | Other :  0.99136263
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00038198277  | Other :  0.99961793
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.033093687  | Other :  0.96690625
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00078849314  | Other :  0.99921143
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99950933  | Other :  0.0004906113
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0042312783  | Other :  0.9957688
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9134134  | Other :  0.08658655
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Defining ROC Function

# %%
def compute_roc(y_true, y_score):
    """ 
    Computing the "Receiving Operating Characteristic curve" and area
    """
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_true, y_score) 
    auroc = auc(false_positive_rate, true_positive_rate) 
    return false_positive_rate, true_positive_rate, auroc

# %% [markdown]
# ## Plotting the ROC

# %%
def plot_roc(y_true, y_score):
    """ 
    Ploting the Receiving Operating Characteristic curve
    """
    false_positive_rate, true_positive_rate, auroc = compute_roc(y_true, y_score)
    plt.figure(figsize=(10,6))
    plt.grid()
    plt.plot(false_positive_rate, 
             true_positive_rate, 
             color='darkorange',
             lw=2, 
             label='ROC curve (area = {:.2f})'.format(auroc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('Receiver operating characteristic example', fontsize=15)
    plt.legend(loc="lower right", fontsize=14)
    plt.show()

# %%
plot_roc(pd.DataFrame(Test_lab)[0],Pred_bin)

# %% [markdown]
# ## Calculating the True Positives, True Negatives, False Positives, False Negatives

# %%
def positive_negative_measurement(y_true, y_score):
    # Initialization
    TRUE_POSITIVE = 0
    FALSE_POSITIVE = 0
    TRUE_NEGATIVE = 0
    FALSE_NEGATIVE = 0
    
    # Calculating the model
    for i in range(len(y_score)):
        if y_true[i] == y_score[i] == 1:
            TRUE_POSITIVE += 1
        if (y_score[i] == 1) and (y_true[i] != y_score[i]):
            FALSE_POSITIVE += 1
        if y_true[i] == y_score[i] == 0:
            TRUE_NEGATIVE += 1
        if (y_score[i] == 0) and (y_true[i] != y_score[i]):
            FALSE_NEGATIVE += 1

    return(TRUE_POSITIVE, FALSE_POSITIVE, TRUE_NEGATIVE, FALSE_NEGATIVE)

# %%
TRUE_POSITIVE, FALSE_POSITIVE, TRUE_NEGATIVE, FALSE_NEGATIVE = positive_negative_measurement(pd.DataFrame(Test_lab)[0],Pred_bin)
postives_negatives = [[TRUE_POSITIVE, FALSE_POSITIVE], 
                      [FALSE_NEGATIVE, TRUE_NEGATIVE]]

# %% [markdown]
# ## Displaying the Confusion Matrix before accounting for uncertaintly

# %%
sns.set()
labels =  np.array([['True positive: ' + str(TRUE_POSITIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%",
                     'False positive: ' + str(FALSE_POSITIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%"],
                    ['False negative: ' + str(FALSE_NEGATIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%",
                     'True negative: ' + str(TRUE_NEGATIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%"]])
plt.figure(figsize = (13, 10))
sns.heatmap(postives_negatives, annot = labels, linewidths = 0.1, fmt="", cmap = 'RdYlGn')

# %% [markdown]
# ## Model Recall, Precision and F1 Score before accounting for uncertaintly

# %%
#True Positive Rate/Recall
Recall = TRUE_POSITIVE / (TRUE_POSITIVE + FALSE_NEGATIVE)
print("Model Recall: ", Recall)
# Out:
# Model Recall:  0.7407407407407407

# %%
# Precision | positive predictive value (PPV)
precision = TRUE_POSITIVE / (TRUE_POSITIVE + FALSE_POSITIVE)
print("Precision: ", precision)
# Out:
# Precision:  0.6666666666666666

# %%
F1 = 2*precision*Recall/(precision+Recall)
print("F1 value: ", F1)
# Out:
# F1 value:  0.7017543859649122

# %% [markdown]
# ## Running the Monte Carlo Simulations to Obtain Model Uncertainty through distribution of outcomes

# %%
MC_Predictions = []
MC_Predictions_bin=[]
for i in tqdm.tqdm(range(500)):
    y_p = Testing_Model.predict(Test_img)
    Y_bin = y_p.argmax(axis=0)
    MC_Predictions .append(y_p)
    MC_Predictions_bin.append(Y_bin)
# Out:
# 100%|██████████| 500/500 [03:49<00:00,  2.18it/s]

# %%
for i in range(len(MC_Predictions)):
    for j in range(len(MC_Predictions[0])):
        temp=MC_Predictions[i][j][0]
        MC_Predictions[i][j][0]=MC_Predictions[i][j][1]
        MC_Predictions[i][j][1]=temp

# %%
accs = []
for y_p in MC_Predictions:
    acc = accuracy_score(pd.DataFrame(Test_lab)[0], y_p.argmax(axis=1))
    accs.append(acc)
print("Accuracy: {:.1%}".format(sum(accs)/len(accs)))
# Out:
# Accuracy: 83.9%

# %% [markdown]
# ## Visualising the accuracies for different simulations

# %%
plt.hist(accs);

# %% [markdown]
# ## Let us calculate mean melanoma probability for a random image

# %%
img = 18
plt.imshow(Test_img[img][:,:,:])
plt.axis('off')
plt.title("Image 18")
# Out:
# Text(0.5, 1.0, 'Image 18')

# %%
p0 = np.array([p[img] for p in MC_Predictions])
print("Calculated Label: {}".format(p0.mean(axis=0).argmax()))
print("True label: {}".format(1-(Test_lab[img].argmax())))
print()
# probability + variance
for i, (prob, var) in enumerate(zip(p0.mean(axis=0), p0.std(axis=0))):
    print("class: {}; probability: {:.1%}; Variance: {:.2%} ".format(i, prob, var))
# Out:
# Calculated Label: 0
# True label: 0
#
# class: 0; probability: 99.8%; Variance: 0.20%
# class: 1; probability: 0.2%; Variance: 0.20%

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,3))

for i, ax in enumerate(fig.get_axes()):
    ax.hist(p0[:,i], bins=100, range=(0,1))
    ax.set_title( "class: {}".format(i))
    ax.label_outer()

# %% [markdown]
# ## Let us find the image for which the model's uncertainty is the highest (In terms of probability)

# %%
max_means = []
preds = []
for idx in range(len(MC_Predictions[0])):
    px = np.array([p[idx] for p in MC_Predictions])
    preds.append(px.mean(axis=0).argmax())
    max_means.append(px.mean(axis=0).max())

# %%
Most_Uncertain=(np.array(max_means)).argsort()[:10]

# %%
plt.imshow(Test_img[Most_Uncertain[0]][:,:,:])
plt.axis('off')
plt.title("Image {}: Most Uncertain Outcome".format(Most_Uncertain[0]))
# Out:
# Text(0.5, 1.0, 'Image 32: Most Uncertain Outcome')

# %% [markdown]
# ## Let us visualise the images and probability distribution for the two classes for most uncertain classifications based on the monte carlo simulation

# %%
Most_Certain=(np.array(max_means)).argsort()[10:]

# %%
for i in range(len(Most_Uncertain)):
    fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (10, 1))

    ax[0].imshow(Test_img[Most_Uncertain[i]])
    ax[0].set_title( "Image {}".format(Most_Uncertain[i]))
    ax[0].axis('off')
    p = np.array([p[Most_Uncertain[i]] for p in MC_Predictions])
    ax[1].hist(p[:,0], bins=100, range=(0,1))
    ax[1].set_title( "class: {}".format(0))
    ax[1].label_outer()
    ax[2].hist(p[:,1], bins=100, range=(0,1))
    ax[2].set_title( "class: {}".format(1))
    ax[2].label_outer()

# %% [markdown]
# ## Let us visualise the images and probability distribution for the two classes for most certain classifications based on the monte carlo simulation

# %%
for i in range(len(Most_Uncertain)):
    fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (10, 1))

    ax[0].imshow(Test_img[Most_Certain[i]])
    ax[0].set_title( "Image {}".format(Most_Certain[i]))
    ax[0].axis('off')
    p = np.array([p[Most_Certain[i]] for p in MC_Predictions])
    ax[1].hist(p[:,0], bins=100, range=(0,1))
    ax[1].set_title( "class: {}".format(0))
    ax[1].label_outer()
    ax[2].hist(p[:,1], bins=100, range=(0,1))
    ax[2].set_title( "class: {}".format(1))
    ax[2].label_outer()

# %% [markdown]
# ## Let us assume that the model uses 95% as the threshold for uncertain outcomes.
# ## All outcomes for which classification probability is less than 95% would be deemed uncertain by the model, instead of classifying uncertain outcomes
# ## So only the outcomes where model certainty>95% would be used to calculate accuracy, for remaining cases, model does not provide outcome
# ## The probabilities have been calculated using monte carlo simulation and thus present a statistical element to the problem of classification

# %%
Model_Confidence = .95

# %%
len(MC_Predictions[0])
# Out:
# 100

# %%
inverse=[]
for i in  range(len(MC_Predictions[0])):
    temp2=[]
    for j in range(len(MC_Predictions)):
        temp = MC_Predictions[j][i]
        temp2.append(temp)
    inverse.append(temp2)

# %%
Y_Certain_Lab=[]
Y_Certain_Pred=[]
Not_Certain=[]
for j in range(len(max_means)):
    if max_means[j]>Model_Confidence:
        Y_Certain_Lab.append(pd.DataFrame(Test_lab)[0][j])
        Y_Certain_Pred.append(Pred_bin[j])
        Not_Certain.append(1000)
    else:
        Not_Certain.append(j)

# %% [markdown]
# ## ROC goes up when we only allow model to provide certain outcomes

# %%
plot_roc(Y_Certain_Lab,Y_Certain_Pred)

# %%
def positive_negative_measurement(y_true, y_score):
    # Initialization
    TRUE_POSITIVE = 0
    FALSE_POSITIVE = 0
    TRUE_NEGATIVE = 0
    FALSE_NEGATIVE = 0
    
    # Calculating the model
    for i in range(len(y_score)):
        if y_true[i] == y_score[i] == 1:
            TRUE_POSITIVE += 1
        if (y_score[i] == 1) and (y_true[i] != y_score[i]):
            FALSE_POSITIVE += 1
        if y_true[i] == y_score[i] == 0:
            TRUE_NEGATIVE += 1
        if (y_score[i] == 0) and (y_true[i] != y_score[i]):
            FALSE_NEGATIVE += 1

    return(TRUE_POSITIVE, FALSE_POSITIVE, TRUE_NEGATIVE, FALSE_NEGATIVE)

# %%
TRUE_POSITIVE, FALSE_POSITIVE, TRUE_NEGATIVE, FALSE_NEGATIVE = positive_negative_measurement(Y_Certain_Lab,Y_Certain_Pred)
postives_negatives = [[TRUE_POSITIVE, FALSE_POSITIVE], 
                      [FALSE_NEGATIVE, TRUE_NEGATIVE]]

# %% [markdown]
# ## We can clearly see an increase in Precision, Recall and F1 value

# %%
import seaborn as sns
sns.set()
labels =  np.array([['True positive: ' + str(TRUE_POSITIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%",
                     'False positive: ' + str(FALSE_POSITIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%"],
                    ['False negative: ' + str(FALSE_NEGATIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%",
                     'True negative: ' + str(TRUE_NEGATIVE*100/(TRUE_POSITIVE+FALSE_POSITIVE+FALSE_NEGATIVE+TRUE_NEGATIVE))+"%"]])
plt.figure(figsize = (13, 10))
sns.heatmap(postives_negatives, annot = labels, linewidths = 0.1, fmt="", cmap = 'RdYlGn')

# %%
#True Positive Rate/Recall
Recall = TRUE_POSITIVE / (TRUE_POSITIVE + FALSE_NEGATIVE)

# Precision | positive predictive value (PPV)
precision = TRUE_POSITIVE / (TRUE_POSITIVE + FALSE_POSITIVE)

F1 = 2*precision*Recall/(precision+Recall)

# %%
print("Model Recall: ", Recall)
print("Precision: ", precision)
print("F1 value: ", F1)
# Out:
# Model Recall:  0.8125
# Precision:  0.8666666666666667
# F1 value:  0.8387096774193549

# %% [markdown]
# ## Here is how the new outcome would look like in this Bayesian classification

# %%
y_score = []
for index in range(len(Test_lab)): #compute one at a time due to memory constraints
    if(index==Not_Certain[index]):
        print("Model is not sure about the outcome with >95% Certainty about Image Number",index)
        print("---------------------------------------------------------------------------")
    else:
        print("Predicted values..." + "Melanoma : ", Predictions[index][0], " | Other : ", Predictions[index][1])
        print("Real values..." + "Melanoma : ", Test_lab[index][1], " | Other : ", Test_lab[index][0])
        print("---------------------------------------------------------------------------")
# Out:
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9988244  | Other :  0.0011755447
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 2
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99998474  | Other :  1.5315034e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9855151  | Other :  0.014484862
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 5
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  1.4700817e-09
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 7
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.999905  | Other :  9.505901e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  1.2972887e-23
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 10
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.014398994  | Other :  0.985601
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.994173  | Other :  0.0058270046
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9995208  | Other :  0.0004792856
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999994  | Other :  6.506337e-07
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.001302589  | Other :  0.99869746
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9854144  | Other :  0.014585648
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9986731  | Other :  0.0013269375
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99655557  | Other :  0.0034444486
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999336  | Other :  6.643927e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0038314771  | Other :  0.99616855
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 21
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 22
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  5.319883e-38
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9998715  | Other :  0.00012852286
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 26
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.1659518e-05  | Other :  0.9999883
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0013905978  | Other :  0.9986094
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 29
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 30
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 31
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 32
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9997745  | Other :  0.00022546168
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999962  | Other :  3.8548997e-06
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999156  | Other :  8.437029e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  8.3354573e-10
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.92604303  | Other :  0.07395696
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 39
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 40
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 41
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99136704  | Other :  0.008632952
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0005901145  | Other :  0.9994099
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99770254  | Other :  0.0022974645
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9938877  | Other :  0.0061122915
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.022485964  | Other :  0.977514
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 47
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.95206505  | Other :  0.04793492
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  4.1012258e-14  | Other :  1.0
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99909437  | Other :  0.00090565835
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.024598334  | Other :  0.97540164
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999999  | Other :  1.4961458e-07
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 55
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.007488618  | Other :  0.9925114
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999939  | Other :  6.071169e-06
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 58
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999888  | Other :  1.1201301e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999981  | Other :  1.9054804e-06
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 62
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 63
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  5.988654e-09
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  4.6356918e-10
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 66
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0027492845  | Other :  0.99725074
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.997981  | Other :  0.0020190717
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 71
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 72
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99996614  | Other :  3.3809076e-05
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99983954  | Other :  0.00016042202
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  7.9351945e-38
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999999  | Other :  1.1086043e-07
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 77
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.017818838  | Other :  0.9821812
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 79
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  9.678149e-15
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  5.0176228e-09
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  9.624238e-06  | Other :  0.99999034
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  1.1358287e-20
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9999994  | Other :  6.324352e-07
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99989104  | Other :  0.00010899135
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 86
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  1.0  | Other :  0.0
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9922266  | Other :  0.0077733686
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 90
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.00030078864  | Other :  0.99969923
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 92
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99136263  | Other :  0.008637434
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 94
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 95
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.99921143  | Other :  0.00078849314
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.0004906113  | Other :  0.99950933
# Real values...Melanoma :  0.0  | Other :  1.0
# ---------------------------------------------------------------------------
# Predicted values...Melanoma :  0.9957688  | Other :  0.0042312783
# Real values...Melanoma :  1.0  | Other :  0.0
# ---------------------------------------------------------------------------
# Model is not sure about the outcome with >95% Certainty about Image Number 99
# ---------------------------------------------------------------------------

# %% [markdown]
# ## -x-x-
